# %%
import pandas as pd

# %%
print("This data was exported from Wordpress.")
print("The blog this data is based on is viewable at lofipython.com.")
csv = "https://raw.githubusercontent.com/erickbytes/lofipy/main/pythonmarketer.wordpress.com_referrers_day_08_18_2023_08_18_2023.csv"
referrers = pd.read_csv(csv, names=["referrer", "visitors", "temp"])
referrers = referrers.drop("temp", axis=1)
referrers.head(5)
# Out:
# This data was exported from Wordpress.
# The blog this data is based on is viewable at lofipython.com.
#                                         referrer  visitors
# 0                                 Search Engines     36537
# 1                 Search Engines > Google Search     13687
# 2    Search Engines > Google Search > google.com     12959
# 3  Search Engines > Google Search > google.co.in        73
# 4     Search Engines > Google Search > google.de        70

# %%
referrers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 507 entries, 0 to 506
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   referrer  507 non-null    object
#  1   visitors  507 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 8.0+ KB

# %%
top_50 = referrers.nlargest(50, "visitors").style.hide()
top_50
# Out:
# <style type="text/css">
# </style>
# <table id="T_c85d6">
#   <thead>
#     <tr>
#       <th id="T_c85d6_level0_col0" class="col_heading level0 col0" >referrer</th>
#       <th id="T_c85d6_level0_col1" class="col_heading level0 col1" >visitors</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c85d6_row0_col0" class="data row0 col0" >Search Engines</td>
#       <td id="T_c85d6_row0_col1" class="data row0 col1" >36537</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row1_col0" class="data row1 col0" >Search Engines > Google Search</td>
#       <td id="T_c85d6_row1_col1" class="data row1 col1" >13687</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row2_col0" class="data row2 col0" >Search Engines > Bing</td>
#       <td id="T_c85d6_row2_col1" class="data row2 col1" >13154</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row3_col0" class="data row3 col0" >Search Engines > Google Search > google.com</td>
#       <td id="T_c85d6_row3_col1" class="data row3 col1" >12959</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row4_col0" class="data row4 col0" >Search Engines > Bing > bing.com</td>
#       <td id="T_c85d6_row4_col1" class="data row4 col1" >12129</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row5_col0" class="data row5 col0" >Search Engines > duckduckgo.com</td>
#       <td id="T_c85d6_row5_col1" class="data row5 col1" >7955</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row6_col0" class="data row6 col0" >Search Engines > duckduckgo.com > /</td>
#       <td id="T_c85d6_row6_col1" class="data row6 col1" >7945</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row7_col0" class="data row7 col0" >Search Engines > Yahoo Search</td>
#       <td id="T_c85d6_row7_col1" class="data row7 col1" >1250</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row8_col0" class="data row8 col0" >ecosia.org</td>
#       <td id="T_c85d6_row8_col1" class="data row8 col1" >906</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row9_col0" class="data row9 col0" >Search Engines > Bing > bing.com</td>
#       <td id="T_c85d6_row9_col1" class="data row9 col1" >541</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row10_col0" class="data row10 col0" >Search Engines > Yahoo Search > search.yahoo.com</td>
#       <td id="T_c85d6_row10_col1" class="data row10 col1" >507</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row11_col0" class="data row11 col0" >Instagram</td>
#       <td id="T_c85d6_row11_col1" class="data row11 col1" >506</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row12_col0" class="data row12 col0" >Instagram > l.instagram.com</td>
#       <td id="T_c85d6_row12_col1" class="data row12 col1" >495</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row13_col0" class="data row13 col0" >Search Engines > Bing > cn.bing.com</td>
#       <td id="T_c85d6_row13_col1" class="data row13 col1" >446</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row14_col0" class="data row14 col0" >qwant.com</td>
#       <td id="T_c85d6_row14_col1" class="data row14 col1" >267</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row15_col0" class="data row15 col0" >Search Engines > Yandex</td>
#       <td id="T_c85d6_row15_col1" class="data row15 col1" >264</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row16_col0" class="data row16 col0" >github.com</td>
#       <td id="T_c85d6_row16_col1" class="data row16 col1" >239</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row17_col0" class="data row17 col0" >Search Engines > Baidu</td>
#       <td id="T_c85d6_row17_col1" class="data row17 col1" >226</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row18_col0" class="data row18 col0" >github.com > /tableau/server-client-python/issues/332</td>
#       <td id="T_c85d6_row18_col1" class="data row18 col1" >225</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row19_col0" class="data row19 col0" >Search Engines > Yahoo Search > in.search.yahoo.com</td>
#       <td id="T_c85d6_row19_col1" class="data row19 col1" >207</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row20_col0" class="data row20 col0" >Search Engines > Yandex > yandex.ru</td>
#       <td id="T_c85d6_row20_col1" class="data row20 col1" >187</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row21_col0" class="data row21 col0" >WordPress.com Reader</td>
#       <td id="T_c85d6_row21_col1" class="data row21 col1" >177</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row22_col0" class="data row22 col0" >Twitter</td>
#       <td id="T_c85d6_row22_col1" class="data row22 col1" >143</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row23_col0" class="data row23 col0" >WordPress Android App</td>
#       <td id="T_c85d6_row23_col1" class="data row23 col1" >132</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row24_col0" class="data row24 col0" >WordPress Android App > com.google.android.googlequicksearchbox</td>
#       <td id="T_c85d6_row24_col1" class="data row24 col1" >121</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row25_col0" class="data row25 col0" >Facebook</td>
#       <td id="T_c85d6_row25_col1" class="data row25 col1" >76</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row26_col0" class="data row26 col0" >Search Engines > Google Search > google.co.in</td>
#       <td id="T_c85d6_row26_col1" class="data row26 col1" >73</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row27_col0" class="data row27 col0" >Search Engines > Google Search > google.de</td>
#       <td id="T_c85d6_row27_col1" class="data row27 col1" >70</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row28_col0" class="data row28 col0" >Search Engines > Google Search > google.com.hk</td>
#       <td id="T_c85d6_row28_col1" class="data row28 col1" >70</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row29_col0" class="data row29 col0" >Search Engines > Google Search > google.ca</td>
#       <td id="T_c85d6_row29_col1" class="data row29 col1" >55</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row30_col0" class="data row30 col0" >Search Engines > Yahoo Search > uk.search.yahoo.com</td>
#       <td id="T_c85d6_row30_col1" class="data row30 col1" >54</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row31_col0" class="data row31 col0" >Search Engines > Google Search > google.co.uk</td>
#       <td id="T_c85d6_row31_col1" class="data row31 col1" >44</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row32_col0" class="data row32 col0" >Search Engines > Yandex > yandex.ru</td>
#       <td id="T_c85d6_row32_col1" class="data row32 col1" >43</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row33_col0" class="data row33 col0" >Search Engines > Google Search > google.fr</td>
#       <td id="T_c85d6_row33_col1" class="data row33 col1" >41</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row34_col0" class="data row34 col0" >Search Engines > Yahoo Search > fr.search.yahoo.com</td>
#       <td id="T_c85d6_row34_col1" class="data row34 col1" >39</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row35_col0" class="data row35 col0" >Search Engines > Yahoo Search > it.search.yahoo.com</td>
#       <td id="T_c85d6_row35_col1" class="data row35 col1" >32</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row36_col0" class="data row36 col0" >Search Engines > Yahoo Search > r.search.yahoo.com</td>
#       <td id="T_c85d6_row36_col1" class="data row36 col1" >31</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row37_col0" class="data row37 col0" >joecodeswell.wordpress.com</td>
#       <td id="T_c85d6_row37_col1" class="data row37 col1" >31</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row38_col0" class="data row38 col0" >joecodeswell.wordpress.com > /2011/05/25/web2py-dal-quick-reference/</td>
#       <td id="T_c85d6_row38_col1" class="data row38 col1" >29</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row39_col0" class="data row39 col0" >prod.uhrs.playmsn.com</td>
#       <td id="T_c85d6_row39_col1" class="data row39 col1" >29</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row40_col0" class="data row40 col0" >prod.uhrs.playmsn.com > /</td>
#       <td id="T_c85d6_row40_col1" class="data row40 col1" >28</td>
#     </tr>
#     <tr>
#       <td id="T_c85d6_row41_col0" class="data row41 col0" >Search Engines > Google Search > google.com/search</td>
#       <td id="T_c85d6_row41_col1" class="data row41 col1" >24

# %%
# Including the word search for generic search engine category / other smaller search engines.
search_engines = [
    "google",
    "duckduckgo",
    "baidu",
    "yahoo",
    "bing",
    "qwant",
    "yandex",
    "ecosia",
    "oceanhero",
    "dogpile",
    "swisscows",
    "lilo",
    "you.com",
    "startpage",
    "metager",
    "neeva",
    "presearch",
    "gutefrage",
    "search"
]
search_engines = "|".join(search_engines)
print(f"These search engines have recorded at least 1 person sent in blog traffic:\n\n{search_engines.replace('|',', ')}")
search_referrals = referrers[
    referrers.referrer.str.contains(pat=search_engines, regex=True, case=False)
].reset_index(drop=True)
search_referrals.head(10)
# Out:
# These search engines have recorded at least 1 person sent in blog traffic:
#
# google, duckduckgo, baidu, yahoo, bing, qwant, yandex, ecosia, oceanhero, dogpile, swisscows, lilo, you.com, startpage, metager, neeva, presearch, gutefrage, search
#                                             referrer  visitors
# 0                                     Search Engines     36537
# 1                     Search Engines > Google Search     13687
# 2        Search Engines > Google Search > google.com     12959
# 3      Search Engines > Google Search > google.co.in        73
# 4         Search Engines > Google Search > google.de        70
# 5     Search Engines > Google Search > google.com.hk        70
# 6         Search Engines > Google Search > google.ca        55
# 7      Search Engines > Google Search > google.co.uk        44
# 8         Search Engines > Google Search > google.fr        41
# 9  Search Engines > Google Search > google.com/se...        24

# %%
search_pct = search_referrals.index.size / referrers.index.size
print(f"{search_pct:.0%} of blog referral traffic sources were from search engines.")
print(f"{1-search_pct:.0%} of blog referral traffic sources were from other sources like social media or other blogs.")
# Out:
# 77% of blog referral traffic sources were from search engines.
# 23% of blog referral traffic sources were from other sources like social media or other blogs.

# %%
# Show the top non-search referral sources.
nonsearch_referrals = referrers[
    ~referrers.referrer.str.contains(pat=search_engines, regex=True, case=False)
].reset_index(drop=True)
print(f"Non-search referrals do not contain:\n\n{search_engines.replace('|',', ')}")
nonsearch_referrals.nlargest(10, "visitors").reset_index(drop=True)
# Out:
# Non-search referrals do not contain:
#
# google, duckduckgo, baidu, yahoo, bing, qwant, yandex, ecosia, oceanhero, dogpile, swisscows, lilo, you.com, startpage, metager, neeva, presearch, gutefrage, search
#                                             referrer  visitors
# 0                                          Instagram       506
# 1                        Instagram > l.instagram.com       495
# 2                                         github.com       239
# 3  github.com > /tableau/server-client-python/iss...       225
# 4                               WordPress.com Reader       177
# 5                                            Twitter       143
# 6                              WordPress Android App       132
# 7                                           Facebook        76
# 8                         joecodeswell.wordpress.com        31
# 9  joecodeswell.wordpress.com > /2011/05/25/web2p...        29

# %%
print("Grab 25 non-search referrers at random. Type ctrl + enter in this cell to randomize the view of sources.")
nonsearch_referrals.sample(n=25).sort_values(
    by="visitors", ascending=False
).reset_index(drop=True)
# Out:
# Grab 25 non-search referrers at random. Type ctrl + enter in this cell to randomize the view of sources.
#                                              referrer  visitors
# 0                         Instagram > l.instagram.com       495
# 1                                          github.com       239
# 2                               WordPress Android App       132
# 3                           prod.uhrs.playmsn.com > /        28
# 4                                     jcchouinard.com        12
# 5                       confluence.itk-engineering.de         4
# 6                              blog.pythonlibrary.org         2
# 7                                              Pocket         2
# 8                                   adfs.contiwan.com         2
# 9                          blog.pythonlibrary.org > /         1
# 10                                   caracabe.com > /         1
# 11                                translatetheweb.com         1
# 12                                 fbj.fantuanshe.com         1
# 13                                     todayposts.com         1
# 14  Instagram > l.instagram.com/?u=https%3A%2F%2Fp...         1
# 15                           gateway.zscalerthree.net         1
# 16          joecodeswell.wordpress.com > /tag/web2py/         1
# 17  Instagram > l.instagram.com/?u=https%3A%2F%2Fp...         1
# 18  pythonmarketer-com.cdn.ampproject.org > /v/s/p...         1
# 19                                       olf.tcyh.net         1
# 20                                     lwjj.saxun.net         1
# 21  dailyseo.xyz/beginner-s-guide-to-blogging-and-...         1
# 22                                     carlbettis.com         1
# 23                                     jbxp.saxun.net         1
# 24  github.com > /erickbytes/divbull/blob/main/REA...         1
