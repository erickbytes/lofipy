# %%
import pandas as pd

# %%
csv = "https://raw.githubusercontent.com/erickbytes/lofipy/main/pythonmarketer.wordpress.com_referrers_day_08_18_2023_08_18_2023.csv"
referrers = pd.read_csv(csv, names=["Referrer", "Visitors", "Temp"])
referrers = referrers.drop("Temp", axis=1)
referrers.head(5)
# Out:
#                                         Referrer  Visitors
# 0                                 Search Engines     36537
# 1                 Search Engines > Google Search     13687
# 2    Search Engines > Google Search > google.com     12959
# 3  Search Engines > Google Search > google.co.in        73
# 4     Search Engines > Google Search > google.de        70

# %%
referrers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 507 entries, 0 to 506
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Referrer  507 non-null    object
#  1   Visitors  507 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 8.0+ KB

# %%
referrers.nlargest(50, "Visitors").style.hide()
# Out:
# <style type="text/css">
# </style>
# <table id="T_139c5">
#   <thead>
#     <tr>
#       <th id="T_139c5_level0_col0" class="col_heading level0 col0" >Referrer</th>
#       <th id="T_139c5_level0_col1" class="col_heading level0 col1" >Visitors</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_139c5_row0_col0" class="data row0 col0" >Search Engines</td>
#       <td id="T_139c5_row0_col1" class="data row0 col1" >36537</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row1_col0" class="data row1 col0" >Search Engines > Google Search</td>
#       <td id="T_139c5_row1_col1" class="data row1 col1" >13687</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row2_col0" class="data row2 col0" >Search Engines > Bing</td>
#       <td id="T_139c5_row2_col1" class="data row2 col1" >13154</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row3_col0" class="data row3 col0" >Search Engines > Google Search > google.com</td>
#       <td id="T_139c5_row3_col1" class="data row3 col1" >12959</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row4_col0" class="data row4 col0" >Search Engines > Bing > bing.com</td>
#       <td id="T_139c5_row4_col1" class="data row4 col1" >12129</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row5_col0" class="data row5 col0" >Search Engines > duckduckgo.com</td>
#       <td id="T_139c5_row5_col1" class="data row5 col1" >7955</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row6_col0" class="data row6 col0" >Search Engines > duckduckgo.com > /</td>
#       <td id="T_139c5_row6_col1" class="data row6 col1" >7945</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row7_col0" class="data row7 col0" >Search Engines > Yahoo Search</td>
#       <td id="T_139c5_row7_col1" class="data row7 col1" >1250</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row8_col0" class="data row8 col0" >ecosia.org</td>
#       <td id="T_139c5_row8_col1" class="data row8 col1" >906</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row9_col0" class="data row9 col0" >Search Engines > Bing > bing.com</td>
#       <td id="T_139c5_row9_col1" class="data row9 col1" >541</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row10_col0" class="data row10 col0" >Search Engines > Yahoo Search > search.yahoo.com</td>
#       <td id="T_139c5_row10_col1" class="data row10 col1" >507</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row11_col0" class="data row11 col0" >Instagram</td>
#       <td id="T_139c5_row11_col1" class="data row11 col1" >506</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row12_col0" class="data row12 col0" >Instagram > l.instagram.com</td>
#       <td id="T_139c5_row12_col1" class="data row12 col1" >495</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row13_col0" class="data row13 col0" >Search Engines > Bing > cn.bing.com</td>
#       <td id="T_139c5_row13_col1" class="data row13 col1" >446</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row14_col0" class="data row14 col0" >qwant.com</td>
#       <td id="T_139c5_row14_col1" class="data row14 col1" >267</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row15_col0" class="data row15 col0" >Search Engines > Yandex</td>
#       <td id="T_139c5_row15_col1" class="data row15 col1" >264</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row16_col0" class="data row16 col0" >github.com</td>
#       <td id="T_139c5_row16_col1" class="data row16 col1" >239</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row17_col0" class="data row17 col0" >Search Engines > Baidu</td>
#       <td id="T_139c5_row17_col1" class="data row17 col1" >226</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row18_col0" class="data row18 col0" >github.com > /tableau/server-client-python/issues/332</td>
#       <td id="T_139c5_row18_col1" class="data row18 col1" >225</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row19_col0" class="data row19 col0" >Search Engines > Yahoo Search > in.search.yahoo.com</td>
#       <td id="T_139c5_row19_col1" class="data row19 col1" >207</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row20_col0" class="data row20 col0" >Search Engines > Yandex > yandex.ru</td>
#       <td id="T_139c5_row20_col1" class="data row20 col1" >187</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row21_col0" class="data row21 col0" >WordPress.com Reader</td>
#       <td id="T_139c5_row21_col1" class="data row21 col1" >177</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row22_col0" class="data row22 col0" >Twitter</td>
#       <td id="T_139c5_row22_col1" class="data row22 col1" >143</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row23_col0" class="data row23 col0" >WordPress Android App</td>
#       <td id="T_139c5_row23_col1" class="data row23 col1" >132</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row24_col0" class="data row24 col0" >WordPress Android App > com.google.android.googlequicksearchbox</td>
#       <td id="T_139c5_row24_col1" class="data row24 col1" >121</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row25_col0" class="data row25 col0" >Facebook</td>
#       <td id="T_139c5_row25_col1" class="data row25 col1" >76</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row26_col0" class="data row26 col0" >Search Engines > Google Search > google.co.in</td>
#       <td id="T_139c5_row26_col1" class="data row26 col1" >73</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row27_col0" class="data row27 col0" >Search Engines > Google Search > google.de</td>
#       <td id="T_139c5_row27_col1" class="data row27 col1" >70</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row28_col0" class="data row28 col0" >Search Engines > Google Search > google.com.hk</td>
#       <td id="T_139c5_row28_col1" class="data row28 col1" >70</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row29_col0" class="data row29 col0" >Search Engines > Google Search > google.ca</td>
#       <td id="T_139c5_row29_col1" class="data row29 col1" >55</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row30_col0" class="data row30 col0" >Search Engines > Yahoo Search > uk.search.yahoo.com</td>
#       <td id="T_139c5_row30_col1" class="data row30 col1" >54</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row31_col0" class="data row31 col0" >Search Engines > Google Search > google.co.uk</td>
#       <td id="T_139c5_row31_col1" class="data row31 col1" >44</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row32_col0" class="data row32 col0" >Search Engines > Yandex > yandex.ru</td>
#       <td id="T_139c5_row32_col1" class="data row32 col1" >43</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row33_col0" class="data row33 col0" >Search Engines > Google Search > google.fr</td>
#       <td id="T_139c5_row33_col1" class="data row33 col1" >41</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row34_col0" class="data row34 col0" >Search Engines > Yahoo Search > fr.search.yahoo.com</td>
#       <td id="T_139c5_row34_col1" class="data row34 col1" >39</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row35_col0" class="data row35 col0" >Search Engines > Yahoo Search > it.search.yahoo.com</td>
#       <td id="T_139c5_row35_col1" class="data row35 col1" >32</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row36_col0" class="data row36 col0" >Search Engines > Yahoo Search > r.search.yahoo.com</td>
#       <td id="T_139c5_row36_col1" class="data row36 col1" >31</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row37_col0" class="data row37 col0" >joecodeswell.wordpress.com</td>
#       <td id="T_139c5_row37_col1" class="data row37 col1" >31</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row38_col0" class="data row38 col0" >joecodeswell.wordpress.com > /2011/05/25/web2py-dal-quick-reference/</td>
#       <td id="T_139c5_row38_col1" class="data row38 col1" >29</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row39_col0" class="data row39 col0" >prod.uhrs.playmsn.com</td>
#       <td id="T_139c5_row39_col1" class="data row39 col1" >29</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row40_col0" class="data row40 col0" >prod.uhrs.playmsn.com > /</td>
#       <td id="T_139c5_row40_col1" class="data row40 col1" >28</td>
#     </tr>
#     <tr>
#       <td id="T_139c5_row41_col0" class="data row41 col0" >Search Engines > Google Search > google.com/search</td>
#       <td id="T_139c5_row41_col1" class="data row41 col1" >24
